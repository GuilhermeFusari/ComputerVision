# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2

# %%
nova_imagem = np.zeros(shape = (1024,1024,3), dtype = np.int16)

# %%
type(nova_imagem)
# Out:
# numpy.ndarray

# %%
nova_imagem.shape
# Out:
# (1024, 1024, 3)

# %%
plt.imshow(nova_imagem)

# %%
nova_imagem[:,:,1] = 255

# %%
plt.imshow(nova_imagem)

# %%
nova_imagem[:,:,2] = 255
plt.imshow(nova_imagem)

# %%
nova_imagem[:,:,0] = 255
plt.imshow(nova_imagem)

# %%
nova_imagem[:,:,:] = 0
plt.imshow(nova_imagem)

# %%
cv2.rectangle(nova_imagem, pt1 = (200, 250), pt2 = (400, 450), color = (255,0,0), thickness = 20 )
cv2.rectangle(nova_imagem, pt1 = (400, 650), pt2 = (800, 950), color = (0,255,0), thickness = 20 )

plt.imshow(nova_imagem)
